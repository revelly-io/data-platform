# %% [markdown]
# # Local Iceberg exploration
#
# Start with `mise run jupyter`.
#
# Prerequisites:
#
# ```bash
# mise run infra:up
# mise run catalog:apply --env local --layer refined --domain sample --table orders
# mise run sample:ingest
# ```

# %%
from spark_app.common.config.loader import ConfigLoader
from spark_app.common.spark_session import build_spark_session

spark = build_spark_session("notebooks.sample", ConfigLoader.load_global("local"))
print("Spark session ready")
# Out:
# Spark session ready

# %%
spark.sql("SHOW TABLES IN iceberg.refined.sample").show(truncate=False)
# Out:
# +--------------+---------+-----------+
# |namespace     |tableName|isTemporary|
# +--------------+---------+-----------+
# |refined.sample|orders   |false      |
# +--------------+---------+-----------+

# %%
spark.table("iceberg.refined.sample.orders").orderBy("order_id").show(truncate=False)
# Out:
# +--------+-----------+---------+------+----------+
# |order_id|customer_id|status   |amount|order_date|
# +--------+-----------+---------+------+----------+
# |1001    |42         |pending  |29.99 |2026-07-01|
# |1002    |42         |shipped  |54.5  |2026-07-02|
# |1003    |7          |delivered|120.0 |2026-07-03|
# |1004    |19         |pending  |15.25 |2026-07-04|
# |1005    |7          |shipped  |88.1  |2026-07-05|
# |1006    |31         |delivered|42.75 |2026-07-06|
# +--------+-----------+---------+------+----------+
